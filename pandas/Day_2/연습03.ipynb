# %% [markdown]
# ###  필요한 라이브러리 임포트

# %%
import pandas as pd
import numpy as np
import os

# %%
os.getcwd()
# Out:
# 'C:\\sona\\KDT\\pandas\\Day_2'

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'auto-mpg.csv',
#  'Euro_2012_stats_TEAM.csv',
#  'Example-01.ipynb',
#  'matzipData.csv',
#  'Pandas-05.ipynb',
#  'Pandas-06.ipynb',
#  '남북한발전전력량.xlsx',
#  '소상공인시장진흥공단_상가업소정보_의료기관.csv',
#  '연습03.ipynb',
#  '연습04.ipynb',
#  '주가데이터.xlsx']

# %% [markdown]
# ### **read_csv를 통해 데이터를 올바른 형태로 불러온 뒤 euro12 저장해주세요**
#
# 파일: 유로2012에 참가한 전체 팀의 통계값파일인 './data/Euro_2012_stats_TEAM.csv'

# %%
df = pd.read_csv( './data/Euro_2012_stats_TEAM.csv')
df
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 0               Croatia      4               13                12
# 1        Czech Republic      4               13                18
# 2               Denmark      4               10                10
# 3               England      5               11                18
# 4                France      3               22                24
# 5               Germany     10               32                32
# 6                Greece      5                8                18
# 7                 Italy      6               34                45
# 8           Netherlands      2               12                36
# 9                Poland      2               15                23
# 10             Portugal      6               22                42
# 11  Republic of Ireland      1                7                12
# 12               Russia      5                9                31
# ...

# %%
df.to_csv("./data/euro12.csv")

# %%
os.listdir('./data')
# Out:
# ['.ipynb_checkpoints',
#  'auto-mpg.csv',
#  'euro12.csv',
#  'Euro_2012_stats_TEAM.csv',
#  'matzipData.csv',
#  '남북한발전전력량.xlsx',
#  '소상공인시장진흥공단_상가업소정보_의료기관.csv',
#  '주가데이터.xlsx']

# %%
euro12 = pd.read_csv("./data/euro12.csv", index_col=0)

# %% [markdown]
# ### Goal 칼럼만 조회해주세요

# %%
df["Goals"]
# Out:
# 0      4
# 1      4
# 2      4
# 3      5
# 4      3
# 5     10
# 6      5
# 7      6
# 8      2
# 9      2
# 10     6
# 11     1
# 12     5
# 13    12
# 14     5
# 15     2
# Name: Goals, dtype: int64

# %% [markdown]
# ### 몇 팀이 Euro2012에 참가했나요?
#
# 16

# %%
df["Team"].count()
# Out:
# 16

# %% [markdown]
# ### 데이터셋은 몇 개의 열로 이루어져 있나요?
#
# 35

# %%
df.shape[1]
# Out:
# 35

# %% [markdown]
# ###  euro12 데이터프레임에서 Team, Yellow Cards, Red Cards 칼럼만 따로 선택하고 이 결과를 discipline 이라는 변수에 저장하세요.

# %%
discipline = euro12[["Team","Yellow Cards","Red Cards"]]

# %%
discipline
# Out:
#                    Team  Yellow Cards  Red Cards
# 0               Croatia             9          0
# 1        Czech Republic             7          0
# 2               Denmark             4          0
# 3               England             5          0
# 4                France             6          0
# 5               Germany             4          0
# 6                Greece             9          1
# 7                 Italy            16          0
# 8           Netherlands             5          0
# 9                Poland             7          1
# 10             Portugal            12          0
# 11  Republic of Ireland             6          1
# 12               Russia             6          0
# 13                Spain            11          0
# 14               Sweden             7          0
# 15              Ukraine             5          0

# %% [markdown]
# ###  discpline칼럼을 정렬하세요.
#
# 정렬기준은 Red Cards기준 내림차순. Red Cards 수가 동일할 경우 Yellow Cards순으로 내림차순 입니다.
#
# > 여러 칼럼을 기준으로 정렬하고자 한다면 ['Red Cards', 'Yellow Cards'] 형태로 정렬 기준을 입력해주면 됩니다.

# %%
discipline.sort_values(['Red Cards', 'Yellow Cards'], ascending=[False,False])
# Out:
#                    Team  Yellow Cards  Red Cards
# 6                Greece             9          1
# 9                Poland             7          1
# 11  Republic of Ireland             6          1
# 7                 Italy            16          0
# 10             Portugal            12          0
# 13                Spain            11          0
# 0               Croatia             9          0
# 1        Czech Republic             7          0
# 14               Sweden             7          0
# 4                France             6          0
# 12               Russia             6          0
# 3               England             5          0
# 8           Netherlands             5          0
# 15              Ukraine             5          0
# 2               Denmark             4          0
# 5               Germany             4          0

# %% [markdown]
# ### 팀당 평균 옐로카드 수를 구하세요
#
# 7.0

# %%
round(discipline["Yellow Cards"].mean())
# Out:
# 7

# %% [markdown]
# ### 7골 이상 득점한 팀을 조회하세요
#
# Germany, Spain

# %%
euro12[euro12["Goals"]>=7]
# Out:
#        Team  Goals  Shots on target  Shots off target Shooting Accuracy  \
# 5   Germany     10               32                32             47.8%
# 13    Spain     12               42                33             55.9%
#
#    % Goals-to-shots  Total shots (inc. Blocked)  Hit Woodwork  Penalty goals  \
# 5             15.6%                          80             2              1
# 13            16.0%                         100             0              1
#
#     Penalties not scored  ...  Saves made  Saves-to-shots ratio  Fouls Won  \
# 5                      0  ...          10                 62.6%         63
# 13                     0  ...          15                 93.8%        102
#
#    Fouls Conceded  Offsides  Yellow Cards  Red Cards  Subs on  Subs off  \
# 5              49        12             4          0       15        15
# 13             83        19            11          0       17        17
#
#     Players Used
# 5             17
# 13            18
#
# ...

# %% [markdown]
# ### 팀명이 G로 시작하는 팀을 조회하세요
#
# Germany, Greece

# %%
euro12[euro12["Team"].str.startswith("G")]
# Out:
#       Team  Goals  Shots on target  Shots off target Shooting Accuracy  \
# 5  Germany     10               32                32             47.8%
# 6   Greece      5                8                18             30.7%
#
#   % Goals-to-shots  Total shots (inc. Blocked)  Hit Woodwork  Penalty goals  \
# 5            15.6%                          80             2              1
# 6            19.2%                          32             1              1
#
#    Penalties not scored  ...  Saves made  Saves-to-shots ratio  Fouls Won  \
# 5                     0  ...          10                 62.6%         63
# 6                     1  ...          13                 65.1%         67
#
#   Fouls Conceded  Offsides  Yellow Cards  Red Cards  Subs on  Subs off  \
# 5             49        12             4          0       15        15
# 6             48        12             9          1       12        12
#
#    Players Used
# 5            17
# 6            20
#
# [2 rows x 35 columns]

# %% [markdown]
# ### 처음부터 7번째 칼럼까지만 조회하세요

# %%
euro12.iloc[:,:7]
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 0               Croatia      4               13                12
# 1        Czech Republic      4               13                18
# 2               Denmark      4               10                10
# 3               England      5               11                18
# 4                France      3               22                24
# 5               Germany     10               32                32
# 6                Greece      5                8                18
# 7                 Italy      6               34                45
# 8           Netherlands      2               12                36
# 9                Poland      2               15                23
# 10             Portugal      6               22                42
# 11  Republic of Ireland      1                7                12
# 12               Russia      5                9                31
# ...

# %% [markdown]
# ### 끝에서 3개의 칼럼만 제외하고 euro12 데이터프레임을 조회하세요

# %%
euro12.iloc[:,:-3]
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 0               Croatia      4               13                12
# 1        Czech Republic      4               13                18
# 2               Denmark      4               10                10
# 3               England      5               11                18
# 4                France      3               22                24
# 5               Germany     10               32                32
# 6                Greece      5                8                18
# 7                 Italy      6               34                45
# 8           Netherlands      2               12                36
# 9                Poland      2               15                23
# 10             Portugal      6               22                42
# 11  Republic of Ireland      1                7                12
# 12               Russia      5                9                31
# ...

# %% [markdown]
# ### England, Italy, Russia의 Shooting Accuracy만 조회하세요
#
# 행은 3행(England, Italy, Russia)
# 열은 2열(Team, Shooting Accuracy)

# %%
euro12.loc[[3,7,12],["Team","Shooting Accuracy"]]
# Out:
#        Team Shooting Accuracy
# 3   England             50.0%
# 7     Italy             43.0%
# 12   Russia             22.5%
